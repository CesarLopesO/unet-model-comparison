# %%
# Bloco 1: Configuração do Caminho do Dataset

import os

# Caminhos Relativos para o Dataset ISIC
DATASET_DIR = "../datasets"
IMAGE_DIR_TRAIN = os.path.join(DATASET_DIR, "image", "train")
MASK_DIR_TRAIN = os.path.join(DATASET_DIR, "mask", "train")
IMAGE_DIR_VAL = os.path.join(DATASET_DIR, "image", "validation")
MASK_DIR_VAL = os.path.join(DATASET_DIR, "mask", "validation")

print("📁 Caminhos do Dataset Configurados:")
print(f"Imagens de Treino: {IMAGE_DIR_TRAIN}")
print(f"Máscaras de Treino: {MASK_DIR_TRAIN}")
print(f"Imagens de Validação: {IMAGE_DIR_VAL}")
print(f"Máscaras de Validação: {MASK_DIR_VAL}")
# Out:
# 📁 Caminhos do Dataset Configurados:
# Imagens de Treino: ../datasets/image/train
# Máscaras de Treino: ../datasets/mask/train
# Imagens de Validação: ../datasets/image/validation
# Máscaras de Validação: ../datasets/mask/validation

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# Bloco Extra: Definição do Modelo Attention U-Net

class AttentionBlock(nn.Module):
    def __init__(self, F_g, F_l, F_int):
        super(AttentionBlock, self).__init__()
        self.W_g = nn.Sequential(
            nn.Conv2d(F_g, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )

        self.W_x = nn.Sequential(
            nn.Conv2d(F_l, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )

        self.psi = nn.Sequential(
            nn.Conv2d(F_int, 1, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )

        self.relu = nn.ReLU(inplace=True)

    def forward(self, g, x):
        g1 = self.W_g(g)
        x1 = self.W_x(x)
        psi = self.relu(g1 + x1)
        psi = self.psi(psi)
        return x * psi


class AttentionUNet(nn.Module):
    def __init__(self, num_classes=1):
        super(AttentionUNet, self).__init__()

        # Encoder
        self.encoder1 = self.conv_block(3, 64)
        self.encoder2 = self.conv_block(64, 128)
        self.encoder3 = self.conv_block(128, 256)
        self.encoder4 = self.conv_block(256, 512)

        # Bottleneck
        self.bottleneck = self.conv_block(512, 1024)

        # Decoder + Attention
        self.up4 = self.up_conv(1024, 512)
        self.att4 = AttentionBlock(F_g=512, F_l=512, F_int=256)
        self.decoder4 = self.conv_block(1024, 512)

        self.up3 = self.up_conv(512, 256)
        self.att3 = AttentionBlock(F_g=256, F_l=256, F_int=128)
        self.decoder3 = self.conv_block(512, 256)

        self.up2 = self.up_conv(256, 128)
        self.att2 = AttentionBlock(F_g=128, F_l=128, F_int=64)
        self.decoder2 = self.conv_block(256, 128)

        self.up1 = self.up_conv(128, 64)
        self.att1 = AttentionBlock(F_g=64, F_l=64, F_int=32)
        self.decoder1 = self.conv_block(128, 64)

        # Output
        self.output_layer = nn.Conv2d(64, num_classes, kernel_size=1, stride=1, padding=0)

    def conv_block(self, in_channels, out_channels):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def up_conv(self, in_channels, out_channels):
        return nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2)

    def forward(self, x):
        # Encoder
        e1 = self.encoder1(x)
        e2 = self.encoder2(F.max_pool2d(e1, kernel_size=2, stride=2))
        e3 = self.encoder3(F.max_pool2d(e2, kernel_size=2, stride=2))
        e4 = self.encoder4(F.max_pool2d(e3, kernel_size=2, stride=2))

        # Bottleneck
        b = self.bottleneck(F.max_pool2d(e4, kernel_size=2, stride=2))

        # Decoder + Attention
        d4 = self.up4(b)
        a4 = self.att4(d4, e4)
        d4 = torch.cat((a4, d4), dim=1)
        d4 = self.decoder4(d4)

        d3 = self.up3(d4)
        a3 = self.att3(d3, e3)
        d3 = torch.cat((a3, d3), dim=1)
        d3 = self.decoder3(d3)

        d2 = self.up2(d3)
        a2 = self.att2(d2, e2)
        d2 = torch.cat((a2, d2), dim=1)
        d2 = self.decoder2(d2)

        d1 = self.up1(d2)
        a1 = self.att1(d1, e1)
        d1 = torch.cat((a1, d1), dim=1)
        d1 = self.decoder1(d1)

        # Output
        out = self.output_layer(d1)
        return out
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f4b9a7f5fd0>>
# Traceback (most recent call last):
#   File "/home/cesar/Pycharm/variacoes_unet/.venv/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:

# %%
import os
import cv2
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np

# Definição do dataset customizado
class ISICDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.image_list = sorted(os.listdir(image_dir))
        self.mask_list = sorted(os.listdir(mask_dir))
        self.transform = transform

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, idx):
        # Garante que o índice não vai além do tamanho do dataset
        idx = idx % len(self.image_list)

        # Caminhos das imagens e máscaras
        img_path = os.path.join(self.image_dir, self.image_list[idx])
        mask_name = self.image_list[idx].replace('.jpg', '_segmentation.png')
        mask_path = os.path.join(self.mask_dir, mask_name)

        # Verificação de Existência
        if not os.path.exists(img_path) or not os.path.exists(mask_path):
            print(f"⚠️ Arquivo não encontrado: {img_path} ou {mask_path}")
            return self.__getitem__((idx + 1) % len(self.image_list))

        # Carregar Imagem e Máscara
        image = cv2.imread(img_path)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

        # Verificação de Corrupção
        if image is None or mask is None:
            print(f"⚠️ Imagem ou Máscara corrompida em: {img_path} ou {mask_path}")
            return self.__getitem__((idx + 1) % len(self.image_list))

        # Conversão e Redimensionamento
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = cv2.resize(image, (256, 256))
        mask = cv2.resize(mask, (256, 256))

        # Normalização
        image = image / 255.0
        mask = (mask > 0).astype(np.float32)  # Converte a máscara para binário (0 ou 1)

        # Conversão para Tensor
        image = torch.tensor(image, dtype=torch.float32).permute(2, 0, 1)
        mask = torch.tensor(mask, dtype=torch.float32).unsqueeze(0)

        return image, mask

# Diretórios do Dataset
DATASET_DIR = "../datasets"
IMAGE_DIR_TRAIN = os.path.join(DATASET_DIR, "image", "train")
MASK_DIR_TRAIN = os.path.join(DATASET_DIR, "mask", "train")
IMAGE_DIR_VAL = os.path.join(DATASET_DIR, "image", "validation")
MASK_DIR_VAL = os.path.join(DATASET_DIR, "mask", "validation")

# Criar dataset e DataLoader
train_dataset = ISICDataset(IMAGE_DIR_TRAIN, MASK_DIR_TRAIN)
val_dataset = ISICDataset(IMAGE_DIR_VAL, MASK_DIR_VAL)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, drop_last=True)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False, drop_last=True)

# Teste: Exibir um batch do DataLoader
batch = next(iter(train_loader))
images, masks = batch

print(f"📊 Formato do batch de imagens: {images.shape}")  # Esperado: [8, 3, 256, 256]
print(f"📊 Formato do batch de máscaras: {masks.shape}")  # Esperado: [8, 1, 256, 256]
# Out:
# 📊 Formato do batch de imagens: torch.Size([8, 3, 256, 256])
# 📊 Formato do batch de máscaras: torch.Size([8, 1, 256, 256])

# %%
# Bloco 4: Funções de Perda e Métricas (Mesmo Padrão do U-Net, U-Net++ e ResUNet)

import torch
import torch.nn.functional as F
import torch.optim as optim

# Configuração do dispositivo (usando CPU)
# Configuração do dispositivo (usando CPU)
device = torch.device("cpu")

# Instanciando o modelo Attention U-Net
model = AttentionUNet(num_classes=1)
model.to(device)

# Função de perda (Binary Cross Entropy com Dice Loss)
def dice_loss(pred, target, smooth=1e-5):
    pred = torch.sigmoid(pred)  # Converte logits para probabilidade
    intersection = (pred * target).sum()
    return 1 - ((2. * intersection + smooth) / (pred.sum() + target.sum() + smooth))

criterion = lambda pred, target: 0.5 * F.binary_cross_entropy_with_logits(pred, target) + 0.5 * dice_loss(pred, target)


# Otimizador
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Funções para métricas
def iou(pred, target, threshold=0.5):
    pred = (torch.sigmoid(pred) > threshold).float()
    intersection = (pred * target).sum()
    union = pred.sum() + target.sum() - intersection
    return (intersection + 1e-5) / (union + 1e-5)

def dice_coefficient(pred, target, threshold=0.5):
    pred = (torch.sigmoid(pred) > threshold).float()
    intersection = (pred * target).sum()
    return (2. * intersection + 1e-5) / (pred.sum() + target.sum() + 1e-5)

def precision(pred, target, threshold=0.5):
    pred = (torch.sigmoid(pred) > threshold).float()
    true_positive = (pred * target).sum()
    predicted_positive = pred.sum()
    return (true_positive + 1e-5) / (predicted_positive + 1e-5)

def recall(pred, target, threshold=0.5):
    pred = (torch.sigmoid(pred) > threshold).float()
    true_positive = (pred * target).sum()
    actual_positive = target.sum()
    return (true_positive + 1e-5) / (actual_positive + 1e-5)

def f1_score(pred, target, threshold=0.5):
    p = precision(pred, target, threshold)
    r = recall(pred, target, threshold)
    return 2 * (p * r) / (p + r + 1e-5)

# %%
# Bloco 5: Função de Treinamento e Validação (Mesmo Padrão do U-Net, U-Net++ e ResUNet)

import torch
import time

# Configuração do dispositivo (usando CPU)
device = torch.device("cpu")
model.to(device)

# Função para treinar o modelo com métricas
def train_model(model, train_loader, val_loader, epochs=10):
    for epoch in range(epochs):
        model.train()
        epoch_loss = 0
        start_time = time.time()

        # Métricas de treino
        train_iou, train_dice, train_precision, train_recall, train_f1 = 0, 0, 0, 0, 0

        for images, masks in train_loader:
            images, masks = images.to(device), masks.to(device)

            # Forward
            outputs = model(images)
            loss = criterion(outputs, masks)

            # Backward
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

            # Calcular métricas para o batch
            train_iou += iou(outputs, masks).item()
            train_dice += dice_coefficient(outputs, masks).item()
            train_precision += precision(outputs, masks).item()
            train_recall += recall(outputs, masks).item()
            train_f1 += f1_score(outputs, masks).item()

        # Validação
        model.eval()
        val_loss = 0
        val_iou, val_dice, val_precision, val_recall, val_f1 = 0, 0, 0, 0, 0

        with torch.no_grad():
            for images, masks in val_loader:
                images, masks = images.to(device), masks.to(device)
                outputs = model(images)
                val_loss += criterion(outputs, masks).item()

                # Calcular métricas para o batch
                val_iou += iou(outputs, masks).item()
                val_dice += dice_coefficient(outputs, masks).item()
                val_precision += precision(outputs, masks).item()
                val_recall += recall(outputs, masks).item()
                val_f1 += f1_score(outputs, masks).item()

        # Exibir progresso
        print(f"📌 Época [{epoch+1}/{epochs}] - Loss Treino: {epoch_loss/len(train_loader):.4f} | Loss Validação: {val_loss/len(val_loader):.4f}")
        print(f"   Métricas de Treino -> IoU: {train_iou/len(train_loader):.4f} | Dice: {train_dice/len(train_loader):.4f} | Prec: {train_precision/len(train_loader):.4f} | Rec: {train_recall/len(train_loader):.4f} | F1: {train_f1/len(train_loader):.4f}")
        print(f"   Métricas de Validação -> IoU: {val_iou/len(val_loader):.4f} | Dice: {val_dice/len(val_loader):.4f} | Prec: {val_precision/len(val_loader):.4f} | Rec: {val_recall/len(val_loader):.4f} | F1: {val_f1/len(val_loader):.4f}")
        print(f"   Tempo da Época: {time.time() - start_time:.2f}s")

# Treinar o modelo com métricas
train_model(model, train_loader, val_loader, epochs=100)
# Out:
# 📌 Época [1/100] - Loss Treino: 0.3740 | Loss Validação: 0.3588
#    Métricas de Treino -> IoU: 0.6082 | Dice: 0.7472 | Prec: 0.7482 | Rec: 0.7768 | F1: 0.7472
#    Métricas de Validação -> IoU: 0.6073 | Dice: 0.7518 | Prec: 0.7188 | Rec: 0.8177 | F1: 0.7517
#    Tempo da Época: 1338.37s
# 📌 Época [2/100] - Loss Treino: 0.2826 | Loss Validação: 0.2759
#    Métricas de Treino -> IoU: 0.6856 | Dice: 0.8090 | Prec: 0.8221 | Rec: 0.8223 | F1: 0.8090
#    Métricas de Validação -> IoU: 0.6831 | Dice: 0.8085 | Prec: 0.8196 | Rec: 0.8172 | F1: 0.8085
#    Tempo da Época: 1334.70s
# 📌 Época [3/100] - Loss Treino: 0.2455 | Loss Validação: 0.2611
#    Métricas de Treino -> IoU: 0.7137 | Dice: 0.8288 | Prec: 0.8424 | Rec: 0.8391 | F1: 0.8288
#    Métricas de Validação -> IoU: 0.6940 | Dice: 0.8158 | Prec: 0.8210 | Rec: 0.8272 | F1: 0.8158
#    Tempo da Época: 1332.08s
# 📌 Época [4/100] - Loss Treino: 0.2160 | Loss Validação: 0.2268
#    Métricas de Treino -> IoU: 0.7405 | Dice: 0.8473 | Prec: 0.8636 | Rec: 0.8492 | F1: 0.8473
#    Métricas de Validação -> IoU: 0.7170 | Dice: 0.8280 | Prec: 0.8981 | Rec: 0.7860 | F1: 0.8280
#    Tempo da Época: 1332.62s
# 📌 Época [5/100] - Loss Treino: 0.1970 | Loss Validação: 0.2444
#    Métricas de Treino -> IoU: 0.7546 | Dice: 0.8572 | Prec: 0.8737 | Rec: 0.8578 | F1: 0.8572
#    Métricas de Validação -> IoU: 0.7063 | Dice: 0.8251 | Prec: 0.7926 | Rec: 0.8800 | F1: 0.8251
#    Tempo da Época: 1332.92s
# 📌 Época [6/100] - Loss Treino: 0.1860 | Loss Validação: 0.2376
#    Métricas de Treino -> IoU: 0.7622 | Dice: 0.8613 | Prec: 0.8768 | Rec: 0.8608 | F1: 0.8613
#    Métricas de Validação -> IoU: 0.7159 | Dice: 0.8314 | Prec: 0.7996 | Rec: 0.8798 | F1: 0.8314
#    Tempo da Época: 1332.57s
# 📌 Época [7/100] - Loss Treino: 0.1808 | Loss Validação: 0.2358
#    Métricas de Treino -> IoU: 0.7619 | Dice: 0.8617 | Prec: 0.8810 | Rec: 0.8597 | F1: 0.8617
#    Métricas de Validação -> IoU: 0.7048 | Dice: 0.8220 | Prec: 0.8566 | Rec: 0.8080 | F1: 0.8220
#    Tempo da Época: 1333.14s
# 📌 Época [8/100] - Loss Treino: 0.1748 | Loss Validação: 0.2103
#    Métricas de Treino -> IoU: 0.7686 | Dice: 0.8657 | Prec: 0.8885 | Rec: 0.8608 | F1: 0.8657
#    Métricas de Validação -> IoU: 0.7341 | Dice: 0.8437 | Prec: 0.8149 | Rec: 0.8865 | F1: 0.8437
#    Tempo da Época: 1332.39s
# 📌 Época [9/100] - Loss Treino: 0.1511 | Loss Validação: 0.2148
#    Métricas de Treino -> IoU: 0.7948 | Dice: 0.8838 | Prec: 0.8982 | Rec: 0.8787 | F1: 0.8838
#    Métricas de Validação -> IoU: 0.7250 | Dice: 0.8376 | Prec: 0.8606 | Rec: 0.8258 | F1: 0.8376
#    Tempo da Época: 1332.81s
# 📌 Época [10/100] - Loss Treino: 0.1508 | Loss Validação: 0.1907
#    Métricas de Treino -> IoU: 0.7947 | Dice: 0.8831 | Prec: 0.8985 | Rec: 0.8782 | F1: 0.8831
#    Métricas de Validação -> IoU: 0.7563 | Dice: 0.8584 | Prec: 0.8459 | Rec: 0.8816 | F1: 0.8584
#    Tempo da Época: 1332.67s
# 📌 Época [11/100] - Loss Treino: 0.1505 | Loss Validação: 0.2085
#    Métricas de Treino -> IoU: 0.7954 | Dice: 0.8838 | Prec: 0.8973 | Rec: 0.8817 | F1: 0.8838
#    Métricas de Validação -> IoU: 0.7404 | Dice: 0.8471 | Prec: 0.8556 | Rec: 0.8507 | F1: 0.8471
#    Tempo da Época: 1332.82s
# 📌 Época [12/100] - Loss Treino: 0.1460 | Loss Validação: 0.1979
#    Métricas de Treino -> IoU: 0.7988 | Dice: 0.8855 | Prec: 0.9010 | Rec: 0.8813 | F1: 0.8855
#    Métricas de Validação -> IoU: 0.7495 | Dice: 0.8513 | Prec: 0.8929 | Rec: 0.8288 | F1: 0.8513
#    Tempo da Época: 1331.80s
# 📌 Época [13/100] - Loss Treino: 0.1392 | Loss Validação: 0.1905
#    Métricas de Treino -> IoU: 0.8063 | Dice: 0.8906 | Prec: 0.9052 | Rec: 0.8845 | F1: 0.8906
#    Métricas de Validação -> IoU: 0.7558 | Dice: 0.8588 | Prec: 0.8457 | Rec: 0.8799 | F1: 0.8588
#    Tempo da Época: 1332.70s
# 📌 Época [14/100] - Loss Treino: 0.1348 | Loss Validação: 0.2269
#    Métricas de Treino -> IoU: 0.8132 | Dice: 0.8953 | Prec: 0.9104 | Rec: 0.8873 | F1: 0.8952
#    Métricas de Validação -> IoU: 0.7252 | Dice: 0.8380 | Prec: 0.8484 | Rec: 0.8362 | F1: 0.8380
#    Tempo da Época: 1335.94s
# 📌 Época [15/100] - Loss Treino: 0.1331 | Loss Validação: 0.2037
#    Métricas de Treino -> IoU: 0.8114 | Dice: 0.8942 | Prec: 0.9096 | Rec: 0.8864 | F1: 0.8942
#    Métricas de Validação -> IoU: 0.7506 | Dice: 0.8521 | Prec: 0.8654 | Rec: 0.8544 | F1: 0.8521
#    Tempo da Época: 1333.86s
# 📌 Época [16/100] - Loss Treino: 0.1278 | Loss Validação: 0.2159
#    Métricas de Treino -> IoU: 0.8194 | Dice: 0.8987 | Prec: 0.9130 | Rec: 0.8917 | F1: 0.8987
#    Métricas de Validação -> IoU: 0.7226 | Dice: 0.8374 | Prec: 0.8060 | Rec: 0.8836 | F1: 0.8374
#    Tempo da Época: 1333.37s
# 📌 Época [17/100] - Loss Treino: 0.1275 | Loss Validação: 0.1791
#    Métricas de Treino -> IoU: 0.8199 | Dice: 0.8986 | Prec: 0.9139 | Rec: 0.8924 | F1: 0.8986
#    Métricas de Validação -> IoU: 0.7709 | Dice: 0.8662 | Prec: 0.8951 | Rec: 0.8500 | F1: 0.8662
#    Tempo da Época: 1335.46s
# 📌 Época [18/100] - Loss Treino: 0.1265 | Loss Validação: 0.1890
#    Métricas de Treino -> IoU: 0.8201 | Dice: 0.8994 | Prec: 0.9157 | Rec: 0.8902 | F1: 0.8994
#    Métricas de Validação -> IoU: 0.7549 | Dice: 0.8572 | Prec: 0.8457 | Rec: 0.8792 | F1: 0.8572
#    Tempo da Época: 1334.82s
# 📌 Época [19/100] - Loss Treino: 0.1176 | Loss Validação: 0.1777
#    Métricas de Treino -> IoU: 0.8325 | Dice: 0.9072 | Prec: 0.9217 | Rec: 0.8987 | F1: 0.9072
#    Métricas de Validação -> IoU: 0.7671 | Dice: 0.8661 | Prec: 0.8676 | Rec: 0.8716 | F1: 0.8661
#    Tempo da Época: 1332.96s
# 📌 Época [20/100] - Loss Treino: 0.1188 | Loss Validação: 0.2125
#    Métricas de Treino -> IoU: 0.8279 | Dice: 0.9043 | Prec: 0.9166 | Rec: 0.8985 | F1: 0.9043
#    Métricas de Validação -> IoU: 0.7323 | Dice: 0.8426 | Prec: 0.8193 | Rec: 0.8796 | F1: 0.8426
#    Tempo da Época: 1335.19s
# 📌 Época [21/100] - Loss Treino: 0.1148 | Loss Validação: 0.2114
#    Métricas de Treino -> IoU: 0.8338 | Dice: 0.9077 | Prec: 0.9203 | Rec: 0.9017 | F1: 0.9077
#    Métricas de Validação -> IoU: 0.7380 | Dice: 0.8462 | Prec: 0.8285 | Rec: 0.8749 | F1: 0.8462
#    Tempo da Época: 1333.83s
# 📌 Época [22/100] - Loss Treino: 0.1116 | Loss Validação: 0.1779
#    Métricas de Treino -> IoU: 0.8389 | Dice: 0.9109 | Prec: 0.9241 | Rec: 0.9038 | F1: 0.9109
#    Métricas de Validação -> IoU: 0.7707 | Dice: 0.8676 | Prec: 0.8686 | Rec: 0.8748 | F1: 0.8676
#    Tempo da Época: 1332.89s
# 📌 Época [23/100] - Loss Treino: 0.1134 | Loss Validação: 0.1831
#    Métricas de Treino -> IoU: 0.8368 | Dice: 0.9098 | Prec: 0.9204 | Rec: 0.9053 | F1: 0.9098
#    Métricas de Validação -> IoU: 0.7678 | Dice: 0.8653 | Prec: 0.8838 | Rec: 0.8566 | F1: 0.8653
#    Tempo da Época: 1334.54s
# 📌 Época [24/100] - Loss Treino: 0.1149 | Loss Validação: 0.1780
#    Métricas de Treino -> IoU: 0.8346 | Dice: 0.9080 | Prec: 0.9201 | Rec: 0.9040 | F1: 0.9080
#    Métricas de Validação -> IoU: 0.7703 | Dice: 0.8668 | Prec: 0.8686 | Rec: 0.8753 | F1: 0.8668
#    Tempo da Época: 1333.72s
# 📌 Época [25/100] - Loss Treino: 0.1092 | Loss Validação: 0.1812
#    Métricas de Treino -> IoU: 0.8409 | Dice: 0.9119 | Prec: 0.9245 | Rec: 0.9054 | F1: 0.9119
#    Métricas de Validação -> IoU: 0.7629 | Dice: 0.8635 | Prec: 0.8456 | Rec: 0.8910 | F1: 0.8635
#    Tempo da Época: 1335.37s
# 📌 Época [26/100] - Loss Treino: 0.1005 | Loss Validação: 0.1896
#    Métricas de Treino -> IoU: 0.8521 | Dice: 0.9192 | Prec: 0.9292 | Rec: 0.9133 | F1: 0.9192
#    Métricas de Validação -> IoU: 0.7603 | Dice: 0.8620 | Prec: 0.8226 | Rec: 0.9118 | F1: 0.8620
#    Tempo da Época: 1334.75s
# 📌 Época [27/100] - Loss Treino: 0.1015 | Loss Validação: 0.1997
#    Métricas de Treino -> IoU: 0.8515 | Dice: 0.9185 | Prec: 0.9293 | Rec: 0.9128 | F1: 0.9185
#    Métricas de Validação -> IoU: 0.7613 | Dice: 0.8598 | Prec: 0.9031 | Rec: 0.8328 | F1: 0.8598
#    Tempo da Época: 1333.50s
# 📌 Época [28/100] - Loss Treino: 0.0972 | Loss Validação: 0.1921
#    Métricas de Treino -> IoU: 0.8567 | Dice: 0.9220 | Prec: 0.9311 | Rec: 0.9165 | F1: 0.9220
#    Métricas de Validação -> IoU: 0.7574 | Dice: 0.8599 | Prec: 0.8169 | Rec: 0.9134 | F1: 0.8599
#    Tempo da Época: 1333.31s
# 📌 Época [29/100] - Loss Treino: 0.0946 | Loss Validação: 0.2042
#    Métricas de Treino -> IoU: 0.8596 | Dice: 0.9236 | Prec: 0.9333 | Rec: 0.9171 | F1: 0.9236
#    Métricas de Validação -> IoU: 0.7484 | Dice: 0.8518 | Prec: 0.8629 | Rec: 0.8532 | F1: 0.8518
#    Tempo da Época: 1334.61s
# 📌 Época [30/100] - Loss Treino: 0.0931 | Loss Validação: 0.1868
#    Métricas de Treino -> IoU: 0.8600 | Dice: 0.9238 | Prec: 0.9329 | Rec: 0.9183 | F1: 0.9238
#    Métricas de Validação -> IoU: 0.7707 | Dice: 0.8681 | Prec: 0.8437 | Rec: 0.9005 | F1: 0.8681
#    Tempo da Época: 1333.08s
# 📌 Época [31/100] - Loss Treino: 0.0897 | Loss Validação: 0.1959
#    Métricas de Treino -> IoU: 0.8646 | Dice: 0.9265 | Prec: 0.9337 | Rec: 0.9223 | F1: 0.9265
#    Métricas de Validação -> IoU: 0.7603 | Dice: 0.8616 | Prec: 0.8157 | Rec: 0.9191 | F1: 0.8616
#    Tempo da Época: 1334.96s
# 📌 Época [32/100] - Loss Treino: 0.0982 | Loss Validação: 0.2118
#    Métricas de Treino -> IoU: 0.8528 | Dice: 0.9194 | Prec: 0.9272 | Rec: 0.9162 | F1: 0.9194
#    Métricas de Validação -> IoU: 0.7442 | Dice: 0.8512 | Prec: 0.8065 | Rec: 0.9091 | F1: 0.8512
#    Tempo da Época: 1331.45s
# 📌 Época [33/100] - Loss Treino: 0.0948 | Loss Validação: 0.1804
#    Métricas de Treino -> IoU: 0.8600 | Dice: 0.9237 | Prec: 0.9325 | Rec: 0.9194 | F1: 0.9237
#    Métricas de Validação -> IoU: 0.7690 | Dice: 0.8672 | Prec: 0.8479 | Rec: 0.8939 | F1: 0.8672
#    Tempo da Época: 1331.41s
# 📌 Época [34/100] - Loss Treino: 0.0879 | Loss Validação: 0.2054
#    Métricas de Treino -> IoU: 0.8665 | Dice: 0.9279 | Prec: 0.9360 | Rec: 0.9221 | F1: 0.9278
#    Métricas de Validação -> IoU: 0.7543 | Dice: 0.8565 | Prec: 0.8587 | Rec: 0.8640 | F1: 0.8565
#    Tempo da Época: 1332.64s
# 📌 Época [35/100] - Loss Treino: 0.0799 | Loss Validação: 0.2054
#    Métricas de Treino -> IoU: 0.8778 | Dice: 0.9344 | Prec: 0.9403 | Rec: 0.9310 | F1: 0.9344
#    Métricas de Validação -> IoU: 0.7524 | Dice: 0.8571 | Prec: 0.8062 | Rec: 0.9209 | F1: 0.8571
#    Tempo da Época: 1330.93s
# 📌 Época [36/100] - Loss Treino: 0.0771 | Loss Validação: 0.2037
#    Métricas de Treino -> IoU: 0.8819 | Dice: 0.9368 | Prec: 0.9423 | Rec: 0.9331 | F1: 0.9368
#    Métricas de Validação -> IoU: 0.7512 | Dice: 0.8558 | Prec: 0.8126 | Rec: 0.9096 | F1: 0.8558
#    Tempo da Época: 1333.20s
# 📌 Época [37/100] - Loss Treino: 0.0818 | Loss Validação: 0.1894
#    Métricas de Treino -> IoU: 0.8759 | Dice: 0.9331 | Prec: 0.9398 | Rec: 0.9294 | F1: 0.9331
#    Métricas de Validação -> IoU: 0.7662 | Dice: 0.8653 | Prec: 0.8529 | Rec: 0.8833 | F1: 0.8653
#    Tempo da Época: 1333.77s
# 📌 Época [38/100] - Loss Treino: 0.0763 | Loss Validação: 0.1828
#    Métricas de Treino -> IoU: 0.8820 | Dice: 0.9369 | Prec: 0.9413 | Rec: 0.9344 | F1: 0.9369
#    Métricas de Validação -> IoU: 0.7806 | Dice: 0.8743 | Prec: 0.8633 | Rec: 0.8900 | F1: 0.8743
#    Tempo da Época: 1333.18s
# 📌 Época [39/100] - Loss Treino: 0.0759 | Loss Validação: 0.1828
#    Métricas de Treino -> IoU: 0.8820 | Dice: 0.9369 | Prec: 0.9417 | Rec: 0.9341 | F1: 0.9369
#    Métricas de Validação -> IoU: 0.7805 | Dice: 0.8730 | Prec: 0.8677 | Rec: 0.8847 | F1: 0.8730
#    Tempo da Época: 1333.48s
# 📌 Época [40/100] - Loss Treino: 0.0692 | Loss Validação: 0.1940
#    Métricas de Treino -> IoU: 0.8923 | Dice: 0.9428 | Prec: 0.9478 | Rec: 0.9393 | F1: 0.9428
#    Métricas de Validação -> IoU: 0.7712 | Dice: 0.8689 | Prec: 0.8334 | Rec: 0.9117 | F1: 0.8689
#    Tempo da Época: 1330.99s
# 📌 Época [41/100] - Loss Treino: 0.0733 | Loss Validação: 0.1952
#    Métricas de Treino -> IoU: 0.8864 | Dice: 0.9392 | Prec: 0.9433 | Rec: 0.9371 | F1: 0.9392
#    Métricas de Validação -> IoU: 0.7725 | Dice: 0.8681 | Prec: 0.8592 | Rec: 0.8839 | F1: 0.8681
#    Tempo da Época: 1333.09s
# 📌 Época [42/100] - Loss Treino: 0.0617 | Loss Validação: 0.1934
#    Métricas de Treino -> IoU: 0.9024 | Dice: 0.9485 | Prec: 0.9511 | Rec: 0.9467 | F1: 0.9485
#    Métricas de Validação -> IoU: 0.7786 | Dice: 0.8734 | Prec: 0.8492 | Rec: 0.9048 | F1: 0.8734
#    Tempo da Época: 1332.12s
# 📌 Época [43/100] - Loss Treino: 0.0655 | Loss Validação: 0.2149
#    Métricas de Treino -> IoU: 0.8970 | Dice: 0.9454 | Prec: 0.9500 | Rec: 0.9424 | F1: 0.9454
#    Métricas de Validação -> IoU: 0.7618 | Dice: 0.8613 | Prec: 0.8536 | Rec: 0.8766 | F1: 0.8612
#    Tempo da Época: 1330.76s
# 📌 Época [44/100] - Loss Treino: 0.0620 | Loss Validação: 0.2041
#    Métricas de Treino -> IoU: 0.9019 | Dice: 0.9483 | Prec: 0.9513 | Rec: 0.9462 | F1: 0.9483
#    Métricas de Validação -> IoU: 0.7561 | Dice: 0.8587 | Prec: 0.8321 | Rec: 0.8933 | F1: 0.8587
#    Tempo da Época: 1332.72s
# 📌 Época [45/100] - Loss Treino: 0.0618 | Loss Validação: 0.2196
#    Métricas de Treino -> IoU: 0.9011 | Dice: 0.9478 | Prec: 0.9512 | Rec: 0.9455 | F1: 0.9478
#    Métricas de Validação -> IoU: 0.7466 | Dice: 0.8529 | Prec: 0.7970 | Rec: 0.9240 | F1: 0.8529
#    Tempo da Época: 1333.22s
# 📌 Época [46/100] - Loss Treino: 0.0615 | Loss Validação: 0.2291
#    Métricas de Treino -> IoU: 0.9017 | Dice: 0.9480 | Prec: 0.9512 | Rec: 0.9461 | F1: 0.9480
#    Métricas de Validação -> IoU: 0.7487 | Dice: 0.8533 | Prec: 0.8537 | Rec: 0.8611 | F1: 0.8533
#    Tempo da Época: 1334.39s
# 📌 Época [47/100] - Loss Treino: 0.0679 | Loss Validação: 0.1958
#    Métricas de Treino -> IoU: 0.8931 | Dice: 0.9432 | Prec: 0.9483 | Rec: 0.9399 | F1: 0.9432
#    Métricas de Validação -> IoU: 0.7764 | Dice: 0.8706 | Prec: 0.8740 | Rec: 0.8760 | F1: 0.8706
#    Tempo da Época: 1332.81s
# 📌 Época [48/100] - Loss Treino: 0.0749 | Loss Validação: 0.1951
#    Métricas de Treino -> IoU: 0.8825 | Dice: 0.9370 | Prec: 0.9414 | Rec: 0.9355 | F1: 0.9370
#    Métricas de Validação -> IoU: 0.7597 | Dice: 0.8615 | Prec: 0.8095 | Rec: 0.9251 | F1: 0.8615
#    Tempo da Época: 1332.52s
# 📌 Época [49/100] - Loss Treino: 0.0585 | Loss Validação: 0.2008
#    Métricas de Treino -> IoU: 0.9064 | Dice: 0.9507 | Prec: 0.9536 | Rec: 0.9487 | F1: 0.9507
#    Métricas de Validação -> IoU: 0.7724 | Dice: 0.8693 | Prec: 0.8465 | Rec: 0.8982 | F1: 0.8693
#    Tempo da Época: 1332.99s
# 📌 Época [50/100] - Loss Treino: 0.0521 | Loss Validação: 0.2120
#    Métricas de Treino -> IoU: 0.9154 | Dice: 0.9557 | Prec: 0.9579 | Rec: 0.9542 | F1: 0.9557
#    Métricas de Validação -> IoU: 0.7711 | Dice: 0.8685 | Prec: 0.8600 | Rec: 0.8835 | F1: 0.8685
#    Tempo da Época: 1331.17s
# 📌 Época [51/100] - Loss Treino: 0.0512 | Loss Validação: 0.2303
#    Métricas de Treino -> IoU: 0.9170 | Dice: 0.9566 | Prec: 0.9583 | Rec: 0.9557 | F1: 0.9566
#    Métricas de Validação -> IoU: 0.7551 | Dice: 0.8581 | Prec: 0.8068 | Rec: 0.9223 | F1: 0.8581
#    Tempo da Época: 1333.35s
# 📌 Época [52/100] - Loss Treino: 0.0503 | Loss Validação: 0.2189
#    Métricas de Treino -> IoU: 0.9177 | Dice: 0.9569 | Prec: 0.9593 | Rec: 0.9552 | F1: 0.9569
#    Métricas de Validação -> IoU: 0.7553 | Dice: 0.8573 | Prec: 0.8340 | Rec: 0.8890 | F1: 0.8573
#    Tempo da Época: 1331.30s
# 📌 Época [53/100] - Loss Treino: 0.0475 | Loss Validação: 0.2177
#    Métricas de Treino -> IoU: 0.9230 | Dice: 0.9599 | Prec: 0.9613 | Rec: 0.9589 | F1: 0.9599
#    Métricas de Validação -> IoU: 0.7732 | Dice: 0.8689 | Prec: 0.8687 | Rec: 0.8743 | F1: 0.8689
#    Tempo da Época: 1332.02s
# 📌 Época [54/100] - Loss Treino: 0.0471 | Loss Validação: 0.2311
#    Métricas de Treino -> IoU: 0.9234 | Dice: 0.9600 | Prec: 0.9620 | Rec: 0.9586 | F1: 0.9600
#    Métricas de Validação -> IoU: 0.7559 | Dice: 0.8585 | Prec: 0.8253 | Rec: 0.8998 | F1: 0.8585
#    Tempo da Época: 1332.08s
# 📌 Época [55/100] - Loss Treino: 0.0499 | Loss Validação: 0.2449
#    Métricas de Treino -> IoU: 0.9191 | Dice: 0.9577 | Prec: 0.9601 | Rec: 0.9559 | F1: 0.9577
#    Métricas de Validação -> IoU: 0.7490 | Dice: 0.8544 | Prec: 0.8013 | Rec: 0.9220 | F1: 0.8544
#    Tempo da Época: 1332.63s
# 📌 Época [56/100] - Loss Treino: 0.0483 | Loss Validação: 0.2374
#    Métricas de Treino -> IoU: 0.9219 | Dice: 0.9592 | Prec: 0.9615 | Rec: 0.9576 | F1: 0.9592
#    Métricas de Validação -> IoU: 0.7619 | Dice: 0.8618 | Prec: 0.8577 | Rec: 0.8757 | F1: 0.8618
#    Tempo da Época: 1333.39s
# 📌 Época [57/100] - Loss Treino: 0.0465 | Loss Validação: 0.2265
#    Métricas de Treino -> IoU: 0.9241 | Dice: 0.9604 | Prec: 0.9624 | Rec: 0.9592 | F1: 0.9604
#    Métricas de Validação -> IoU: 0.7580 | Dice: 0.8593 | Prec: 0.8430 | Rec: 0.8842 | F1: 0.8593
#    Tempo da Época: 1332.40s
# 📌 Época [58/100] - Loss Treino: 0.0437 | Loss Validação: 0.2139
#    Métricas de Treino -> IoU: 0.9285 | Dice: 0.9629 | Prec: 0.9643 | Rec: 0.9619 | F1: 0.9628
#    Métricas de Validação -> IoU: 0.7763 | Dice: 0.8716 | Prec: 0.8587 | Rec: 0.8904 | F1: 0.8716
#    Tempo da Época: 1332.77s
# 📌 Época [59/100] - Loss Treino: 0.0437 | Loss Validação: 0.2356
#    Métricas de Treino -> IoU: 0.9288 | Dice: 0.9630 | Prec: 0.9649 | Rec: 0.9617 | F1: 0.9630
#    Métricas de Validação -> IoU: 0.7827 | Dice: 0.8762 | Prec: 0.8565 | Rec: 0.9014 | F1: 0.8762
#    Tempo da Época: 1332.32s
# 📌 Época [60/100] - Loss Treino: 0.0476 | Loss Validação: 0.2460
#    Métricas de Treino -> IoU: 0.9226 | Dice: 0.9596 | Prec: 0.9616 | Rec: 0.9581 | F1: 0.9596
#    Métricas de Validação -> IoU: 0.7594 | Dice: 0.8601 | Prec: 0.8418 | Rec: 0.8854 | F1: 0.8601
#    Tempo da Época: 1330.67s
# 📌 Época [61/100] - Loss Treino: 0.0403 | Loss Validação: 0.2260
#    Métricas de Treino -> IoU: 0.9341 | Dice: 0.9659 | Prec: 0.9673 | Rec: 0.9648 | F1: 0.9659
#    Métricas de Validação -> IoU: 0.7761 | Dice: 0.8713 | Prec: 0.8574 | Rec: 0.8913 | F1: 0.8713
#    Tempo da Época: 1335.62s
# 📌 Época [62/100] - Loss Treino: 0.0378 | Loss Validação: 0.2247
#    Métricas de Treino -> IoU: 0.9377 | Dice: 0.9678 | Prec: 0.9688 | Rec: 0.9671 | F1: 0.9678
#    Métricas de Validação -> IoU: 0.7790 | Dice: 0.8721 | Prec: 0.8841 | Rec: 0.8678 | F1: 0.8721
#    Tempo da Época: 1331.64s
# 📌 Época [63/100] - Loss Treino: 0.0377 | Loss Validação: 0.2173
#    Métricas de Treino -> IoU: 0.9372 | Dice: 0.9675 | Prec: 0.9690 | Rec: 0.9664 | F1: 0.9675
#    Métricas de Validação -> IoU: 0.7759 | Dice: 0.8717 | Prec: 0.8483 | Rec: 0.9022 | F1: 0.8717
#    Tempo da Época: 1331.97s
# 📌 Época [64/100] - Loss Treino: 0.0364 | Loss Validação: 0.2452
#    Métricas de Treino -> IoU: 0.9396 | Dice: 0.9688 | Prec: 0.9701 | Rec: 0.9679 | F1: 0.9688
#    Métricas de Validação -> IoU: 0.7646 | Dice: 0.8638 | Prec: 0.8643 | Rec: 0.8727 | F1: 0.8638
#    Tempo da Época: 1330.40s
# 📌 Época [65/100] - Loss Treino: 0.0344 | Loss Validação: 0.2353
#    Métricas de Treino -> IoU: 0.9430 | Dice: 0.9706 | Prec: 0.9719 | Rec: 0.9697 | F1: 0.9706
#    Métricas de Validação -> IoU: 0.7745 | Dice: 0.8708 | Prec: 0.8670 | Rec: 0.8802 | F1: 0.8708
#    Tempo da Época: 1331.60s
# 📌 Época [66/100] - Loss Treino: 0.0330 | Loss Validação: 0.2616
#    Métricas de Treino -> IoU: 0.9455 | Dice: 0.9720 | Prec: 0.9730 | Rec: 0.9711 | F1: 0.9719
#    Métricas de Validação -> IoU: 0.7630 | Dice: 0.8632 | Prec: 0.8418 | Rec: 0.8933 | F1: 0.8632
#    Tempo da Época: 1332.72s
# 📌 Época [67/100] - Loss Treino: 0.0323 | Loss Validação: 0.2514
#    Métricas de Treino -> IoU: 0.9462 | Dice: 0.9723 | Prec: 0.9729 | Rec: 0.9720 | F1: 0.9723
#    Métricas de Validação -> IoU: 0.7598 | Dice: 0.8613 | Prec: 0.8317 | Rec: 0.9008 | F1: 0.8613
#    Tempo da Época: 1333.22s
# 📌 Época [68/100] - Loss Treino: 0.0322 | Loss Validação: 0.2546
#    Métricas de Treino -> IoU: 0.9464 | Dice: 0.9724 | Prec: 0.9736 | Rec: 0.9716 | F1: 0.9724
#    Métricas de Validação -> IoU: 0.7566 | Dice: 0.8595 | Prec: 0.8335 | Rec: 0.8943 | F1: 0.8595
#    Tempo da Época: 1333.16s
# 📌 Época [69/100] - Loss Treino: 0.0322 | Loss Validação: 0.2467
#    Métricas de Treino -> IoU: 0.9465 | Dice: 0.9725 | Prec: 0.9732 | Rec: 0.9721 | F1: 0.9725
#    Métricas de Validação -> IoU: 0.7612 | Dice: 0.8624 | Prec: 0.8231 | Rec: 0.9123 | F1: 0.8624
#    Tempo da Época: 1333.29s
# 📌 Época [70/100] - Loss Treino: 0.0323 | Loss Validação: 0.2544
#    Métricas de Treino -> IoU: 0.9465 | Dice: 0.9725 | Prec: 0.9732 | Rec: 0.9719 | F1: 0.9725
#    Métricas de Validação -> IoU: 0.7619 | Dice: 0.8621 | Prec: 0.8643 | Rec: 0.8695 | F1: 0.8621
#    Tempo da Época: 1333.98s
# 📌 Época [71/100] - Loss Treino: 0.0285 | Loss Validação: 0.2462
#    Métricas de Treino -> IoU: 0.9526 | Dice: 0.9757 | Prec: 0.9763 | Rec: 0.9752 | F1: 0.9757
#    Métricas de Validação -> IoU: 0.7761 | Dice: 0.8710 | Prec: 0.8674 | Rec: 0.8836 | F1: 0.8710
#    Tempo da Época: 1332.23s
# 📌 Época [72/100] - Loss Treino: 0.0288 | Loss Validação: 0.2547
#    Métricas de Treino -> IoU: 0.9523 | Dice: 0.9755 | Prec: 0.9762 | Rec: 0.9750 | F1: 0.9755
#    Métricas de Validação -> IoU: 0.7638 | Dice: 0.8634 | Prec: 0.8551 | Rec: 0.8792 | F1: 0.8634
#    Tempo da Época: 1332.64s
# 📌 Época [73/100] - Loss Treino: 0.0782 | Loss Validação: 0.2406
#    Métricas de Treino -> IoU: 0.8828 | Dice: 0.9365 | Prec: 0.9427 | Rec: 0.9339 | F1: 0.9365
#    Métricas de Validação -> IoU: 0.7431 | Dice: 0.8505 | Prec: 0.8152 | Rec: 0.8956 | F1: 0.8505
#    Tempo da Época: 1338.11s
# 📌 Época [74/100] - Loss Treino: 0.0429 | Loss Validação: 0.2487
#    Métricas de Treino -> IoU: 0.9304 | Dice: 0.9638 | Prec: 0.9652 | Rec: 0.9631 | F1: 0.9638
#    Métricas de Validação -> IoU: 0.7651 | Dice: 0.8643 | Prec: 0.8490 | Rec: 0.8879 | F1: 0.8643
#    Tempo da Época: 1332.20s
# 📌 Época [75/100] - Loss Treino: 0.0285 | Loss Validação: 0.2465
#    Métricas de Treino -> IoU: 0.9527 | Dice: 0.9758 | Prec: 0.9759 | Rec: 0.9758 | F1: 0.9758
#    Métricas de Validação -> IoU: 0.7772 | Dice: 0.8719 | Prec: 0.8608 | Rec: 0.8918 | F1: 0.8718
#    Tempo da Época: 1334.35s
# 📌 Época [76/100] - Loss Treino: 0.0258 | Loss Validação: 0.2637
#    Métricas de Treino -> IoU: 0.9569 | Dice: 0.9779 | Prec: 0.9784 | Rec: 0.9776 | F1: 0.9779
#    Métricas de Validação -> IoU: 0.7687 | Dice: 0.8665 | Prec: 0.8551 | Rec: 0.8873 | F1: 0.8665
#    Tempo da Época: 1335.42s
# 📌 Época [77/100] - Loss Treino: 0.0245 | Loss Validação: 0.2546
#    Métricas de Treino -> IoU: 0.9588 | Dice: 0.9789 | Prec: 0.9792 | Rec: 0.9789 | F1: 0.9789
#    Métricas de Validação -> IoU: 0.7718 | Dice: 0.8686 | Prec: 0.8603 | Rec: 0.8850 | F1: 0.8686
#    Tempo da Época: 1333.39s
# 📌 Época [78/100] - Loss Treino: 0.0233 | Loss Validação: 0.2734
#    Métricas de Treino -> IoU: 0.9609 | Dice: 0.9801 | Prec: 0.9803 | Rec: 0.9799 | F1: 0.9800
#    Métricas de Validação -> IoU: 0.7695 | Dice: 0.8664 | Prec: 0.8714 | Rec: 0.8714 | F1: 0.8663
#    Tempo da Época: 1334.37s
# 📌 Época [79/100] - Loss Treino: 0.0218 | Loss Validação: 0.2620
#    Métricas de Treino -> IoU: 0.9635 | Dice: 0.9814 | Prec: 0.9815 | Rec: 0.9813 | F1: 0.9814
#    Métricas de Validação -> IoU: 0.7776 | Dice: 0.8721 | Prec: 0.8704 | Rec: 0.8817 | F1: 0.8721
#    Tempo da Época: 1334.38s
# 📌 Época [80/100] - Loss Treino: 0.0214 | Loss Validação: 0.2630
#    Métricas de Treino -> IoU: 0.9641 | Dice: 0.9817 | Prec: 0.9821 | Rec: 0.9814 | F1: 0.9817
#    Métricas de Validação -> IoU: 0.7745 | Dice: 0.8705 | Prec: 0.8590 | Rec: 0.8900 | F1: 0.8705
#    Tempo da Época: 1334.41s
# 📌 Época [81/100] - Loss Treino: 0.0215 | Loss Validação: 0.2823
#    Métricas de Treino -> IoU: 0.9638 | Dice: 0.9815 | Prec: 0.9817 | Rec: 0.9815 | F1: 0.9815
#    Métricas de Validação -> IoU: 0.7680 | Dice: 0.8663 | Prec: 0.8588 | Rec: 0.8826 | F1: 0.8663
#    Tempo da Época: 1334.56s
# 📌 Época [82/100] - Loss Treino: 0.0218 | Loss Validação: 0.2659
#    Métricas de Treino -> IoU: 0.9630 | Dice: 0.9811 | Prec: 0.9813 | Rec: 0.9811 | F1: 0.9811
#    Métricas de Validação -> IoU: 0.7716 | Dice: 0.8676 | Prec: 0.8847 | Rec: 0.8603 | F1: 0.8676
#    Tempo da Época: 1335.36s
# 📌 Época [83/100] - Loss Treino: 0.0213 | Loss Validação: 0.2993
#    Métricas de Treino -> IoU: 0.9643 | Dice: 0.9818 | Prec: 0.9821 | Rec: 0.9816 | F1: 0.9818
#    Métricas de Validação -> IoU: 0.7554 | Dice: 0.8579 | Prec: 0.8535 | Rec: 0.8724 | F1: 0.8579
#    Tempo da Época: 1335.48s
# 📌 Época [84/100] - Loss Treino: 0.0204 | Loss Validação: 0.2668
#    Métricas de Treino -> IoU: 0.9656 | Dice: 0.9825 | Prec: 0.9825 | Rec: 0.9826 | F1: 0.9825
#    Métricas de Validação -> IoU: 0.7740 | Dice: 0.8693 | Prec: 0.8763 | Rec: 0.8716 | F1: 0.8693
#    Tempo da Época: 1335.61s
# 📌 Época [85/100] - Loss Treino: 0.0214 | Loss Validação: 0.3029
#    Métricas de Treino -> IoU: 0.9642 | Dice: 0.9817 | Prec: 0.9820 | Rec: 0.9816 | F1: 0.9817
#    Métricas de Validação -> IoU: 0.7564 | Dice: 0.8588 | Prec: 0.8476 | Rec: 0.8803 | F1: 0.8588
#    Tempo da Época: 1335.46s
# 📌 Época [86/100] - Loss Treino: 0.0200 | Loss Validação: 0.2806
#    Métricas de Treino -> IoU: 0.9666 | Dice: 0.9830 | Prec: 0.9831 | Rec: 0.9830 | F1: 0.9830
#    Métricas de Validação -> IoU: 0.7684 | Dice: 0.8664 | Prec: 0.8601 | Rec: 0.8811 | F1: 0.8664
#    Tempo da Época: 1335.51s
# 📌 Época [87/100] - Loss Treino: 0.0195 | Loss Validação: 0.2909
#    Métricas de Treino -> IoU: 0.9673 | Dice: 0.9834 | Prec: 0.9834 | Rec: 0.9834 | F1: 0.9834
#    Métricas de Validação -> IoU: 0.7620 | Dice: 0.8623 | Prec: 0.8662 | Rec: 0.8676 | F1: 0.8623
#    Tempo da Época: 1337.04s
# 📌 Época [88/100] - Loss Treino: 0.0193 | Loss Validação: 0.2733
#    Métricas de Treino -> IoU: 0.9675 | Dice: 0.9835 | Prec: 0.9837 | Rec: 0.9833 | F1: 0.9835
#    Métricas de Validação -> IoU: 0.7748 | Dice: 0.8705 | Prec: 0.8599 | Rec: 0.8886 | F1: 0.8705
#    Tempo da Época: 1334.16s
# 📌 Época [89/100] - Loss Treino: 0.0187 | Loss Validação: 0.2796
#    Métricas de Treino -> IoU: 0.9684 | Dice: 0.9839 | Prec: 0.9839 | Rec: 0.9840 | F1: 0.9839
#    Métricas de Validação -> IoU: 0.7702 | Dice: 0.8679 | Prec: 0.8639 | Rec: 0.8795 | F1: 0.8679
#    Tempo da Época: 1334.87s
# 📌 Época [90/100] - Loss Treino: 0.0191 | Loss Validação: 0.2981
#    Métricas de Treino -> IoU: 0.9678 | Dice: 0.9836 | Prec: 0.9838 | Rec: 0.9836 | F1: 0.9836
#    Métricas de Validação -> IoU: 0.7552 | Dice: 0.8590 | Prec: 0.8355 | Rec: 0.8914 | F1: 0.8590
#    Tempo da Época: 1335.29s
# 📌 Época [91/100] - Loss Treino: 0.0188 | Loss Validação: 0.2919
#    Métricas de Treino -> IoU: 0.9683 | Dice: 0.9839 | Prec: 0.9840 | Rec: 0.9838 | F1: 0.9839
#    Métricas de Validação -> IoU: 0.7527 | Dice: 0.8565 | Prec: 0.8254 | Rec: 0.8977 | F1: 0.8565
#    Tempo da Época: 1334.85s
# 📌 Época [92/100] - Loss Treino: 0.0723 | Loss Validação: 0.2205
#    Métricas de Treino -> IoU: 0.8930 | Dice: 0.9418 | Prec: 0.9463 | Rec: 0.9412 | F1: 0.9418
#    Métricas de Validação -> IoU: 0.7530 | Dice: 0.8579 | Prec: 0.8132 | Rec: 0.9138 | F1: 0.8579
#    Tempo da Época: 1335.56s
# 📌 Época [93/100] - Loss Treino: 0.0372 | Loss Validação: 0.2297
#    Métricas de Treino -> IoU: 0.9400 | Dice: 0.9689 | Prec: 0.9699 | Rec: 0.9684 | F1: 0.9689
#    Métricas de Validação -> IoU: 0.7778 | Dice: 0.8730 | Prec: 0.8690 | Rec: 0.8832 | F1: 0.8730
#    Tempo da Época: 1334.70s
# 📌 Época [94/100] - Loss Treino: 0.0202 | Loss Validação: 0.2633
#    Métricas de Treino -> IoU: 0.9660 | Dice: 0.9827 | Prec: 0.9829 | Rec: 0.9825 | F1: 0.9827
#    Métricas de Validação -> IoU: 0.7707 | Dice: 0.8685 | Prec: 0.8504 | Rec: 0.8943 | F1: 0.8684
#    Tempo da Época: 1335.20s
# 📌 Época [95/100] - Loss Treino: 0.0174 | Loss Validação: 0.2746
#    Métricas de Treino -> IoU: 0.9709 | Dice: 0.9852 | Prec: 0.9853 | Rec: 0.9852 | F1: 0.9852
#    Métricas de Validação -> IoU: 0.7750 | Dice: 0.8712 | Prec: 0.8473 | Rec: 0.9023 | F1: 0.8712
#    Tempo da Época: 1332.84s
# 📌 Época [96/100] - Loss Treino: 0.0158 | Loss Validação: 0.2735
#    Métricas de Treino -> IoU: 0.9734 | Dice: 0.9865 | Prec: 0.9867 | Rec: 0.9864 | F1: 0.9865
#    Métricas de Validação -> IoU: 0.7811 | Dice: 0.8747 | Prec: 0.8662 | Rec: 0.8901 | F1: 0.8747
#    Tempo da Época: 1333.54s
# 📌 Época [97/100] - Loss Treino: 0.0152 | Loss Validação: 0.2900
#    Métricas de Treino -> IoU: 0.9744 | Dice: 0.9870 | Prec: 0.9872 | Rec: 0.9869 | F1: 0.9870
#    Métricas de Validação -> IoU: 0.7707 | Dice: 0.8681 | Prec: 0.8551 | Rec: 0.8890 | F1: 0.8681
#    Tempo da Época: 1334.50s
# 📌 Época [98/100] - Loss Treino: 0.0153 | Loss Validação: 0.2853
#    Métricas de Treino -> IoU: 0.9743 | Dice: 0.9870 | Prec: 0.9871 | Rec: 0.9868 | F1: 0.9870
#    Métricas de Validação -> IoU: 0.7746 | Dice: 0.8705 | Prec: 0.8643 | Rec: 0.8843 | F1: 0.8705
#    Tempo da Época: 1335.12s
# 📌 Época [99/100] - Loss Treino: 0.0153 | Loss Validação: 0.2751
#    Métricas de Treino -> IoU: 0.9743 | Dice: 0.9870 | Prec: 0.9870 | Rec: 0.9870 | F1: 0.9869
#    Métricas de Validação -> IoU: 0.7798 | Dice: 0.8738 | Prec: 0.8637 | Rec: 0.8907 | F1: 0.8738
#    Tempo da Época: 1333.19s
# 📌 Época [100/100] - Loss Treino: 0.0153 | Loss Validação: 0.2753
#    Métricas de Treino -> IoU: 0.9741 | Dice: 0.9869 | Prec: 0.9870 | Rec: 0.9868 | F1: 0.9869
#    Métricas de Validação -> IoU: 0.7812 | Dice: 0.8746 | Prec: 0.8657 | Rec: 0.8904 | F1: 0.8746
#    Tempo da Época: 1333.00s
